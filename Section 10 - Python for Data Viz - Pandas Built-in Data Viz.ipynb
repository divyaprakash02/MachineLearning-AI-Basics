# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/divya/Udemy_NumpyPandaBootscamp_sampleFiles/df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 =  pd.read_csv('/Users/divya/Udemy_NumpyPandaBootscamp_sampleFiles/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
#creating histagram
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2['a'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['B'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(x=df1.index,y='B', alpha=0.4)#this one as suggested in tutorial isnt working, the above one results the same result
#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0340965ebaae> in <module>
# ----> 1 df1.plot.line(x=df1.index,y=df1['B'], alpha=0.4)#this one as suggested in tutorial isnt working, the above one results the same result
#       2 #
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1021         as coordinates.
#    1022         """
# -> 1023         return self(kind="line", x=x, y=y, **kwargs)
#    1024
#    1025     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     918                 if is_integer(x) and not data.columns.holds_integer():
#     919                     x = data_cols[x]
# --> 920                 elif not isinstance(data[x], ABCSeries):
#     921                     raise ValueError("x must be a label or position")
# ...

# %%
df1['B'].plot.line(figsize=(12,3), lw=1)
# Out:
# <AxesSubplot:>

# %%
#scatter plots
df1.plot.scatter(x='A',y='B', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B', c= 'C', figsize=(10,6), cmap='coolwarm', alpha=5)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#boxplots
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  1.891387 -0.720225
# 1  0.113116 -1.394165
# 2 -1.736896  0.578572
# 3  0.233421 -0.353237
# 4 -0.104542  0.134768

# %%
df.plot.hexbin(x='a',y='b', gridsize=25, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#kde plot
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#########################EXERCISE########################

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('/Users/divya/Udemy_NumpyPandaBootscamp_sampleFiles/df3')
# %matplotlib inline

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.plot.scatter(x='a', y='b', figsize=(12,3), cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3['a'].plot.hist(bins=25, cmap='coolwarm')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(ls='--',lw=5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3[0:30].plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>
