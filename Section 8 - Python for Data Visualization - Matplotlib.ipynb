# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.show()

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
z = x**3
z
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
#functional method- 
plt.plot(x,y)
#plt.show()  # optional to use if using plot

# %%
plt.plot(x,y,'r-')

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#to create dpi(dots per inch), we use subplots
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#to create dpi(dots per inch), we use subplots
plt.subplot(1,3,1)
plt.plot(x,y,'r')

plt.subplot(1,3,2)
plt.plot(y,x,'b')

plt.subplot(1,3,3)
plt.plot(y,z,'y')

# %%
#object oriented methods

#create an empty canvas
fig = plt.figure()

#adding axes
axes = fig.add_axes([0.1,0.1,0.8,0.8])

#plotting
axes.plot(x,y)

#setting labels
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,.3])

axes1.plot(x,y)
axes1.set_title('Main Plot')
axes2.plot(y,x)
axes2.set_title('Smaller plot')
# Out:
# Text(0.5, 1.0, 'Smaller plot')

# %%
fig = plt.figure();
axes3 = fig.add_axes([0.1,0.1,0.8,0.8])
axes4 = fig.add_axes([0.5,0.15,0.4,.3])

# %%
axes1.plot(x,y)
axes2.plot(y,x)

# %%
#adding subplot

fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('New Plot')

axes.plot(x,z)

# %%
#fig,axes = plt.subplot()
axes = plt.subplot()
axes.plot(x,y)

# %%
axes = plt.subplots(nrows = 1, ncols = 2)
#axes.plot()

# %%
fig,axes = plt.subplots(nrows=3, ncols=3)
plt.tight_layout()
#axes.plot(x,y)

# %%
fig, axes = plt.subplots(1,2)

plt.tight_layout()

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, axes = plt.subplots(1,2)
for current_axes in axes:
    current_axes.plot(x,y)

# %%
fig, axes = plt.subplots(1,1)
axes.plot(x,y)

# %%
fig, axes = plt.subplots(1,2)
axes[0].plot(x,y)
axes[1].plot(z,x)

# %%
#figure size and DPI
fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
#figure size and DPI
fig = plt.figure(figsize=(8,2), dpi = 100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
# do with subplot

fig, axe = plt.subplots(figsize=(3,2))
axe.plot(x,y)

plt.tight_layout()

# %%
fig, axe = plt.subplots(nrows=1, ncols=3, figsize=(3,2))

axe[0].plot(x,y)
axe[1].plot(y,x)
axe[2].plot(x,z)

plt.tight_layout()

# %%
fig, axe = plt.subplots(nrows=3, ncols=1, figsize=(3,2))

axe[0].plot(x,y)
axe[1].plot(y,x)
axe[2].plot(x,z)

plt.tight_layout()

# %%
fig, axe = plt.subplots(nrows=3, ncols=1, figsize=(3,2), dpi=100)

axe[0].plot(x,y)
axe[1].plot(y,x)
axe[2].plot(x,z)

plt.tight_layout()

# %%
#saving a figure
fig.savefig('/Users/divya/Udemy_sampleFiles/figSample1.png', dpi=500)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('Some Title')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.plot(x,y)

# %%
#Legends
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)
ax.plot(y,x)

# %%
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label='X - Squre')
ax.plot(x,x**3, label='X - Cube')

ax.legend()

# %%
#changing color of legends
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, 'b', label='X - Squre')
ax.plot(x,x**3, 'g', label='X - Cube')

ax.legend()

# %%
#locating legends
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, 'b', label='X - Squre')
ax.plot(x,x**3, 'g', label='X - Cube')

ax.legend(loc=0)

# %%
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, 'b', label='X - Squre')
ax.plot(x,x**3, 'g', label='X - Cube')

ax.legend(loc=10)

# %%
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, 'b', label='X - Squre')
ax.plot(x,x**3, 'g', label='X - Cube')

ax.legend(loc=(0.1,0.1))

# %%
#plot appearance

# %%
fg = plt.figure()

amp = fg.add_axes([0,0,1,1])

amp = plt.plot(x,y, 'green') #can use rgb hexcode too

# %%
fg = plt.figure()

amp = fg.add_axes([0,0,1,1])

plt.plot(x,y, 'purple', linewidth=3, alpha=0.5)#alpha - for transparency

# %%
fg = plt.figure()

amp = fg.add_axes([0,0,1,1])

plt.plot(x,y, 'purple', linewidth=3, alpha=0.5, ls=':')#linstyle or ls, can use both, same with linewidth lw

# %%
fg = plt.figure()

amp = fg.add_axes([0,0,1,1])

plt.plot(x,y, 'purple', linewidth=2, alpha=0.5, ls='-', marker='o', markersize=10, markerfacecolor='yellow', markeredgewidth=3
        ,markeredgecolor='green')

# %%
#plot range
fig, axes = plt.subplots(1,3, figsize=(12,4))
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('default axes ranges')

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title('custom axes range')

plt.tight_layout()

# %%
####EXERCISE###

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# Exercise 1
# ** Follow along with these steps: **
#
# ** Create a figure object called fig using plt.figure() **
# ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.set_title("title")
axes.set_xlabel('x')
axes.set_ylabel('y')
plt.plot(x,y)

# %% [markdown]
# Exercise 2¶
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure();
axes3 = fig.add_axes([0,0,1,1])
axes4 = fig.add_axes([0.2,0.5,.2,.2])

# %%
* Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure();
axes1 = fig.add_axes([0,0,1,1])
axes1.set_xlabel('x')
axes1.set_ylabel('y')
plt.plot(x,y)
axes2 = fig.add_axes([0.2,0.5,.2,.2])
axes2.set_xlabel('x')
axes2.set_ylabel('y')
plt.plot(x,y)

# %% [markdown]
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])

axes2 = fig.add_axes([0.2,0.5,.4,.4])

# %%
** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes1.set_xlabel('X')
axes1.set_ylabel('Z')
plt.plot(x,z)


axes2 = fig.add_axes([0.2,0.5,.4,.4])
plt.plot(x,y)
axes2.set_xlabel('X')
axes2.set_ylabel('Y')
axes2.set_xlim(20,22)
axes2.set_ylim(30,50)

fig

# %% [markdown]
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fg = plt.subplots(nrows=1, ncols=2)

# %%
fg = plt.subplots(nrows=1, ncols=2)
axes = fg.set_ar
axes[0].plot(x,y,color="blue", lw=3, ls='--')
axes[1].plot(x,z,color="red", lw=3, ls='-')
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-ae781d226f89> in <module>
#       1 axes = plt.subplots(nrows=1, ncols=2)
# ----> 2 axes[0].plot(x,y,color="blue", lw=3, ls='--')
#       3 axes[1].plot(x,z,color="red", lw=3, ls='-')
#       4 fig
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('default axes ranges')

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title('custom axes range')

plt.tight_layout()
